# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\keerthi\Documents\student_data.csv")
df
# Out:
#            Name  Class Section  RollNo                   Email     PhoneNo  \
# 0  Aarav Sharma     10       A       1  aarav.sharma@gmail.com  9876543210
# 1   Priya Verma     10       A       2   priya.verma@gmail.com  9876543211
# 2     Rohan Das     10       A       3     rohan.das@gmail.com  9876543212
# 3   Sneha Patil     10       B       4   sneha.patil@gmail.com  9876543213
# 4   Kunal Singh     10       B       5   kunal.singh@gmail.com  9876543214
# 5   Ananya Iyer     10       B       6   ananya.iyer@gmail.com  9876543215
# 6    Vikram Rao     10       C       7    vikram.rao@gmail.com  9876543216
# 7    Neha Gupta     10       C       8    neha.gupta@gmail.com  9876543217
# 8   Arjun Mehta     10       C       9   arjun.mehta@gmail.com  9876543218
# 9    Pooja Nair     10       C      10    pooja.nair@gmail.com  9876543219
#
#    Marks
# 0     85
# 1     78
# 2     88
# 3     92
# 4     74
# 5     81
# 6     69
# 7     90
# 8     76
# 9     84

# %%
df.max()
# Out:
# Name                 Vikram Rao
# Class                        10
# Section                       C
# RollNo                       10
# Email      vikram.rao@gmail.com
# PhoneNo              9876543219
# Marks                        92
# dtype: object

# %%
df.min()
# Out:
# Name                 Aarav Sharma
# Class                          10
# Section                         A
# RollNo                          1
# Email      aarav.sharma@gmail.com
# PhoneNo                9876543210
# Marks                          69
# dtype: object

# %%
df["Marks"].mean()
# Out:
# np.float64(81.7)

# %%
df["Marks"].mode()
# Out:
# 0    69
# 1    74
# 2    76
# 3    78
# 4    81
# 5    84
# 6    85
# 7    88
# 8    90
# 9    92
# Name: Marks, dtype: int64

# %%
df["Marks"].median()
# Out:
# 82.5

# %%
df["Marks"].var()
# Out:
# 55.34444444444445

# %%
df["Marks"].std()
# Out:
# 7.439384681843281

# %%
df["Marks"].cov(df["RollNo"])
# Out:
# np.float64(-4.166666666666666)
